# %%
import os
from typing import Dict
from tavily import TavilyClient
from langchain_openai import ChatOpenAI
from langchain_core.tools import tool
from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import MessagesState
from langgraph.graph import START, END, StateGraph
from langgraph.prebuilt import ToolNode
from langgraph.graph.state import CompiledStateGraph
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
from IPython.display import Image, display

# %%
from dotenv import load_dotenv
load_dotenv()
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.0,
    api_key=os.getenv("OPEN_AI_API_KEY")
)

# %%
@tool
def web_search(question:str)->Dict:
    """
    Return top search results for a given search query
    """
    tavily_client = TavilyClient(api_key=os.getenv("TAVILY_API_KEY"))
    response = tavily_client.search(question)
    return response

# %% [markdown]
# **Breakpoints**

# %%
class State(MessagesState):
    question: str
    answer: str

# %%
llm_with_tools = llm.bind_tools([web_search])

# %%
def entry_point(state: State):
    question = state["question"]
    system_message = SystemMessage("You conduct web search to respond to user's questions")
    human_message = HumanMessage(question)
    messages = [system_message, human_message]
    return {"messages": messages}

# %%
def agent(state: State):
    messages = state["messages"]
    ai_message = llm_with_tools.invoke(messages)
    return {"messages": ai_message, "answer": ai_message.content}

# %%
def router(state: MessagesState):
    last_message = state["messages"][-1]
    if last_message.tool_calls:
        return "tools"

    return END

# %%
workflow = StateGraph(State)
workflow.add_node("entry_point", entry_point)
workflow.add_node("agent", agent)
workflow.add_node("tools", ToolNode([web_search]))

workflow.add_edge(START, "entry_point")
workflow.add_edge("entry_point", "agent")
workflow.add_conditional_edges(
    source="agent", 
    path=router, 
    path_map=["tools", END]
)
workflow.add_edge("tools", "agent")

# %%
memory = MemorySaver()
graph = workflow.compile(
    interrupt_before=["tools"], 
    checkpointer=memory
)

# %%
display(
    Image(
        graph.get_graph().draw_mermaid_png()
    )
)

# %%
input_question = {"question": "what's the capital of Brazil?"}
config = {"configurable": {"thread_id": 1}}

# %%
for event in graph.stream(input=input_question, config=config, stream_mode="values"):
    if not event['messages']:
        continue
    event['messages'][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# what's the capital of Brazil?
# ================================== Ai Message ==================================
# Tool Calls:
#   web_search (call_ogo27AESoPdP1AVlWNDAosPS)
#  Call ID: call_ogo27AESoPdP1AVlWNDAosPS
#   Args:
#     question: capital of Brazil

# %%
state = graph.get_state(config=config)

# %%
state
# Out:
# StateSnapshot(values={'messages': [SystemMessage(content="You conduct web search to respond to user's questions", additional_kwargs={}, response_metadata={}, id='b2fcaa6c-965d-4cdd-b3ac-6537bb54384a'), HumanMessage(content="what's the capital of Brazil?", additional_kwargs={}, response_metadata={}, id='97ed6772-9830-4b91-8f22-9466ef90f3e4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_ogo27AESoPdP1AVlWNDAosPS', 'function': {'arguments': '{"question":"capital of Brazil"}', 'name': 'web_search'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 64, 'total_tokens': 80, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--5ff2a415-33c9-4d05-b0ba-bc266cc28568-0', tool_calls=[{'name': 'web_search', 'args': {'question': 'capital of Brazil'}, 'id': 'call_ogo27AESoPdP1AVlWNDAosPS', 'type': 'tool_call'}], usage_metadata={'input_tokens': 64, 'output_tokens': 16, 'total_tokens': 80, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})], 'question': "what's the capital of Brazil?", 'answer': ''}, next=('tools',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0cfe50-ccfb-6a66-8002-7d3932f460c7'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-03T01:11:51.788591+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0cfe50-bb97-6604-8001-a858fa51ff81'}}, tasks=(PregelTask(id='0eef0c40-bba9-76f1-5440-972a2db0121d', name='tools', path=('__pregel_pull', 'tools'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
state.next
# Out:
# ('tools',)

# %%
for event in graph.stream(input=None, config=config, stream_mode="values"):
    if not event['messages']:
        continue
    event['messages'][-1].pretty_print()
# Out:
# ================================== Ai Message ==================================
# Tool Calls:
#   web_search (call_ogo27AESoPdP1AVlWNDAosPS)
#  Call ID: call_ogo27AESoPdP1AVlWNDAosPS
#   Args:
#     question: capital of Brazil
# ================================= Tool Message =================================
# Name: web_search
#
# {"query": "capital of Brazil", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.gov.br/g20/en/about-the-g20/host-cities/brasilia-df", "title": "Brasília - DF - Portal Gov.br", "content": "**Brasília** is the capital of Brazil and the seat of government of the Federal District and the federal government. Brasília is the political center of Brazil. The capital of Brazil is more than just a city, and its construction was a milestone in the history of urbanism, representing the boldness and modernity of a growing nation. • Museu Nacional da República - National Museum of the Republic • Parque Nacional de Brasília (Água Mineral) - Brasília National Park (Mineral Water) This avenue runs through the city and is lined with impressive monuments such as the National Congress, the Planalto Palace and the Cathedral. The JK Memorial is dedicated to Brasília's founder, Juscelino Kubitschek, and the Indigenous Peoples Memorial is a tribute to the diverse cultures of the indigenous peoples of Brazil.", "score": 0.99893504, "raw_content": null}, {"url": "https://www.ebsco.com/research-starters/history/brazil-builds-new-capital-city", "title": "Brazil Builds a New Capital City | Research Starters - EBSCO", "content": "The establishment of Brasília as Brazil's new capital city marked a significant shift in the nation's development strategy. *The Brazilian government built its capital city Brasília in the hope of increasing economic growth in the country’s vast interior and of increasing Brazil’s international status. He adopted an economic plan called developmentalism, which centered on the creation of a new capital city in the middle of the country; the capital would lead to the rapid growth of Brazil’s interior. While the design of the principal government buildings, including the president’s palace, drew admiration for Niemeyer, the city’s newly arrived workers crowded into slums, which came to be known as “squatments.” Government officials charged with meeting the timetables for completion of the new city ignored the development of these living spaces; one slum area, Free Town, soon became a permanent part of the city’s profile.", "score": 0.99566853, "raw_content": null}, {"url": "https://en.wikipedia.org/wiki/Capitals_of_Brazil", "title": "Capitals of Brazil - Wikipedia", "content": "Jump to content ## Contents * Page information * Cite this page * Download QR code * Download as PDF | This article **needs additional citations for verification**. Please help improve this article by adding citations to reliable sources. In the 17th century, Rio de Janeiro became a far more practical export port than Salvador, and the colonial administration was moved in 1763. The Portuguese capital was temporarily transferred from Europe to Rio de Janeiro. In the 1950s plans were considered for moving the federal capital from the east coast to the interior; the interior was sparsely populated and it was hoped that moving the capital to the region would help populate the area. 2. **^** \"Historic Centre of Salvador de Bahia\". Retrieved 12 February 2024. Retrieved from \"\" Categories: Hidden categories:", "score": 0.9954615, "raw_content": null}, {"url": "https://www.youtube.com/shorts/vr6suZwQ9i8", "title": "what's the capital of brazil? #shorts - YouTube", "content": "📍#shorts - YouTube Back Image 1 Search  Search with your voice  Image 2 📍#shorts 2x Image 3 Search Share Image 4 Image 5 If playback doesn't begin shortly, try restarting your device. Video unavailable Share - [x] Include playlist  An error occurred while retrieving sharing information. Image 6 📍#shorts Share Image 7 Image 8 Image 9 📍#shorts 📍#shorts#brazil#brasilia#capital#trivia#chargers#nfl…...more  Image 11: Go to video 📍#shorts Next video  2x Search If playback doesn't begin shortly, try restarting your device. Videos you watch may be added to the TV's watch history and influence TV recommendations. To avoid this, cancel and sign in to YouTube o ...
# ================================== Ai Message ==================================
#
# The capital of Brazil is **Brasília**. It serves as the political center of the country and was established to promote the development of the interior regions of Brazil. For more information, you can visit the [official government portal](https://www.gov.br/g20/en/about-the-g20/host-cities/brasilia-df).

# %% [markdown]
# **Human Approval**

# %%
def human_in_the_loop_run(graph:CompiledStateGraph, question:str, thread_id:int):
    input_question = {"question": question}
    config = {"configurable": {"thread_id": thread_id}}
    for event in graph.stream(input=input_question, config=config, stream_mode="values"):
        if not event['messages']:
            continue
        event['messages'][-1].pretty_print()
    
    human_input = input("Do you approve the tool calling? (YES or NO): ")
    if human_input.lower() == "yes":
        for event in graph.stream(input=None, config=config, stream_mode="values"):
            if not event['messages']:
                continue
            event['messages'][-1].pretty_print()
    
    else:
        SystemMessage("Workflow aborted by a human").pretty_print()

# %%
human_in_the_loop_run(
    graph=graph,
    question="what's the capital of Brazil?",
    thread_id=2,
)
# Out:
# ================================ Human Message =================================
#
# what's the capital of Brazil?
# ================================== Ai Message ==================================
# Tool Calls:
#   web_search (call_wSjks7WI0DwjMKBG4btlfSnU)
#  Call ID: call_wSjks7WI0DwjMKBG4btlfSnU
#   Args:
#     question: capital of Brazil
# ================================== Ai Message ==================================
# Tool Calls:
#   web_search (call_wSjks7WI0DwjMKBG4btlfSnU)
#  Call ID: call_wSjks7WI0DwjMKBG4btlfSnU
#   Args:
#     question: capital of Brazil
# ================================= Tool Message =================================
# Name: web_search
#
# {"query": "capital of Brazil", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.gov.br/g20/en/about-the-g20/host-cities/brasilia-df", "title": "Brasília - DF - Portal Gov.br", "content": "**Brasília** is the capital of Brazil and the seat of government of the Federal District and the federal government. Brasília is the political center of Brazil. The capital of Brazil is more than just a city, and its construction was a milestone in the history of urbanism, representing the boldness and modernity of a growing nation. • Museu Nacional da República - National Museum of the Republic • Parque Nacional de Brasília (Água Mineral) - Brasília National Park (Mineral Water) This avenue runs through the city and is lined with impressive monuments such as the National Congress, the Planalto Palace and the Cathedral. The JK Memorial is dedicated to Brasília's founder, Juscelino Kubitschek, and the Indigenous Peoples Memorial is a tribute to the diverse cultures of the indigenous peoples of Brazil.", "score": 0.99893504, "raw_content": null}, {"url": "https://www.ebsco.com/research-starters/history/brazil-builds-new-capital-city", "title": "Brazil Builds a New Capital City | Research Starters - EBSCO", "content": "The establishment of Brasília as Brazil's new capital city marked a significant shift in the nation's development strategy. *The Brazilian government built its capital city Brasília in the hope of increasing economic growth in the country’s vast interior and of increasing Brazil’s international status. He adopted an economic plan called developmentalism, which centered on the creation of a new capital city in the middle of the country; the capital would lead to the rapid growth of Brazil’s interior. While the design of the principal government buildings, including the president’s palace, drew admiration for Niemeyer, the city’s newly arrived workers crowded into slums, which came to be known as “squatments.” Government officials charged with meeting the timetables for completion of the new city ignored the development of these living spaces; one slum area, Free Town, soon became a permanent part of the city’s profile.", "score": 0.99566853, "raw_content": null}, {"url": "https://en.wikipedia.org/wiki/Capitals_of_Brazil", "title": "Capitals of Brazil - Wikipedia", "content": "Jump to content ## Contents * Page information * Cite this page * Download QR code * Download as PDF | This article **needs additional citations for verification**. Please help improve this article by adding citations to reliable sources. In the 17th century, Rio de Janeiro became a far more practical export port than Salvador, and the colonial administration was moved in 1763. The Portuguese capital was temporarily transferred from Europe to Rio de Janeiro. In the 1950s plans were considered for moving the federal capital from the east coast to the interior; the interior was sparsely populated and it was hoped that moving the capital to the region would help populate the area. 2. **^** \"Historic Centre of Salvador de Bahia\". Retrieved 12 February 2024. Retrieved from \"\" Categories: Hidden categories:", "score": 0.9954615, "raw_content": null}, {"url": "https://www.youtube.com/shorts/vr6suZwQ9i8", "title": "what's the capital of brazil? #shorts - YouTube", "content": "📍#shorts - YouTube Back Image 1 Search  Search with your voice  Image 2 📍#shorts 2x Image 3 Search Share Image 4 Image 5 If playback doesn't begin shortly, try restarting your device. Video unavailable Share - [x] Include playlist  An error occurred while retrieving sharing information. Image 6 📍#shorts Share Image 7 Image 8 Image 9 📍#shorts 📍#shorts#brazil#brasilia#capital#trivia#chargers#nfl…...more  Image 11: Go to video 📍#shorts Next video  2x Search If playback doesn't begin shortly, try restarting your device. Videos you watch may be added to the TV's watch history and influence TV recommendations. To avoid this, cancel and sign in to YouTube o ...
# ================================== Ai Message ==================================
#
# The capital of Brazil is **Brasília**. It serves as the political center of the country and was established to promote the development of the interior regions of Brazil. The city is known for its modernist architecture and urban planning.

# %%
human_in_the_loop_run(
    graph=graph,
    question="what's the capital of Mexico?",
    thread_id=3,
)
# Out:
# ================================ Human Message =================================
#
# what's the capital of Mexico?
# ================================== Ai Message ==================================
# Tool Calls:
#   web_search (call_0V7s9ZabfDwo8NAffbcmFu9w)
#  Call ID: call_0V7s9ZabfDwo8NAffbcmFu9w
#   Args:
#     question: capital of Mexico
# ================================ System Message ================================
#
# Workflow aborted by a human

# %% [markdown]
# **Human Revision**

# %%
memory = MemorySaver()
graph = workflow.compile(
    interrupt_before=["agent"], 
    checkpointer=memory
)

# %%
display(
    Image(
        graph.get_graph().draw_mermaid_png()
    )
)

# %%
def human_in_the_loop_run(graph:CompiledStateGraph, question:str, thread_id:int):
    input_question = {"question": question}
    config = {"configurable": {"thread_id": thread_id}}
    for event in graph.stream(input=input_question, config=config, stream_mode="values"):
        if not event['messages']:
            continue
        event['messages'][-1].pretty_print()

    human_input = input("Do you want to proceed with this question? (YES or NO): ")
    
    if human_input.lower() == "no":
        human_input = input("So what should be the question? ")
        human_message = HumanMessage(content=human_input)
        system_message = SystemMessage("Workflow edited by a human")
        system_message.pretty_print()
        graph.update_state(
            config=config,
            values={
                "messages": [
                    system_message,
                    human_message,
                ]
            },
        )

        for event in graph.stream(input=None, config=config, stream_mode="values"):
            if not event['messages']:
                continue
            event['messages'][-1].pretty_print()
    
    for event in graph.stream(input=None, config=config, stream_mode="values"):
        if not event['messages']:
            continue
        event['messages'][-1].pretty_print()

# %%
human_in_the_loop_run(
    graph=graph,
    question="what's the capital of Brazil?",
    thread_id=4,
)
# Out:
# ================================ Human Message =================================
#
# what's the capital of Brazil?
# ================================ Human Message =================================
#
# what's the capital of Brazil?
# ================================== Ai Message ==================================
# Tool Calls:
#   web_search (call_50N4sus5iMF1661i0Rr0MeXu)
#  Call ID: call_50N4sus5iMF1661i0Rr0MeXu
#   Args:
#     question: What is the capital of Brazil?
# ================================= Tool Message =================================
# Name: web_search
#
# {"query": "What is the capital of Brazil?", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.gov.br/g20/en/about-the-g20/host-cities/brasilia-df", "title": "Brasília - DF - Portal Gov.br", "content": "**Brasília** is the capital of Brazil and the seat of government of the Federal District and the federal government. Brasília is the political center of Brazil. The capital of Brazil is more than just a city, and its construction was a milestone in the history of urbanism, representing the boldness and modernity of a growing nation. • Museu Nacional da República - National Museum of the Republic • Parque Nacional de Brasília (Água Mineral) - Brasília National Park (Mineral Water) This avenue runs through the city and is lined with impressive monuments such as the National Congress, the Planalto Palace and the Cathedral. The JK Memorial is dedicated to Brasília's founder, Juscelino Kubitschek, and the Indigenous Peoples Memorial is a tribute to the diverse cultures of the indigenous peoples of Brazil.", "score": 0.99860066, "raw_content": null}, {"url": "https://www.ebsco.com/research-starters/history/brazil-builds-new-capital-city", "title": "Brazil Builds a New Capital City | Research Starters - EBSCO", "content": "The establishment of Brasília as Brazil's new capital city marked a significant shift in the nation's development strategy. *The Brazilian government built its capital city Brasília in the hope of increasing economic growth in the country’s vast interior and of increasing Brazil’s international status. He adopted an economic plan called developmentalism, which centered on the creation of a new capital city in the middle of the country; the capital would lead to the rapid growth of Brazil’s interior. While the design of the principal government buildings, including the president’s palace, drew admiration for Niemeyer, the city’s newly arrived workers crowded into slums, which came to be known as “squatments.” Government officials charged with meeting the timetables for completion of the new city ignored the development of these living spaces; one slum area, Free Town, soon became a permanent part of the city’s profile.", "score": 0.98998636, "raw_content": null}, {"url": "https://en.wikipedia.org/wiki/Capitals_of_Brazil", "title": "Capitals of Brazil - Wikipedia", "content": "Jump to content ## Contents * Page information * Cite this page * Download QR code * Download as PDF | This article **needs additional citations for verification**. Please help improve this article by adding citations to reliable sources. In the 17th century, Rio de Janeiro became a far more practical export port than Salvador, and the colonial administration was moved in 1763. The Portuguese capital was temporarily transferred from Europe to Rio de Janeiro. In the 1950s plans were considered for moving the federal capital from the east coast to the interior; the interior was sparsely populated and it was hoped that moving the capital to the region would help populate the area. 2. **^** \"Historic Centre of Salvador de Bahia\". Retrieved 12 February 2024. Retrieved from \"\" Categories: Hidden categories:", "score": 0.98646784, "raw_content": null}, {"url": "https://www.youtube.com/shorts/vr6suZwQ9i8", "title": "what's the capital of brazil? #shorts - YouTube", "content": "📍#shorts - YouTube Back Image 1 Search  Search with your voice  Image 2 📍#shorts 2x Image 3 Search Share Image 4 Image 5 If playback doesn't begin shortly, try restarting your device. Video unavailable Share - [x] Include playlist  An error occurred while retrieving sharing information. Image 6 📍#shorts Share Image 7 Image 8 Image 9 📍#shorts 📍#shorts#brazil#brasilia#capital#trivia#chargers#nfl…...more  Image 11: Go to video 📍#shorts Next video  2x Search If playback doesn't begin shortly, try restarting your device. Videos you watch may be added to the TV's watch history and influence TV recommendations. To avoid this, cancel and sign i ...

# %%
human_in_the_loop_run(
    graph=graph,
    question="what's the capital of Brazil?",
    thread_id=5,
)
# Out:
# ================================ Human Message =================================
#
# what's the capital of Brazil?
# ================================ System Message ================================
#
# Workflow edited by a human
# ================================ Human Message =================================
#
# What is the capital of Germany?
# ================================== Ai Message ==================================
# Tool Calls:
#   web_search (call_5S4TkyksRRGSc3rAo5iuqpka)
#  Call ID: call_5S4TkyksRRGSc3rAo5iuqpka
#   Args:
#     question: What is the capital of Germany?
# ================================= Tool Message =================================
# Name: web_search
#
# {"query": "What is the capital of Germany?", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.bmi.bund.de/EN/topics/constitution/state-symbols/capital/capital-city-artikel.html", "title": "Our Capital City - BMI", "content": "Berlin is not only the capital of the Federal Republic of Germany; it is also the seat of Germany’s federal parliament and government. Since 1 September 2006, Berlin’s role as capital of Germany has been enshrined in the Basic Law. Article 22 (1) (1) provides that “Berlin is the capital of the Federal Republic of Germany.” By then, Berlin had witnessed an eventful history. Frankfurt am Main served as seat of the German Confederation from 1815 to 1866; Bonn was the provisional seat of the Federal Government from 1949 to 1973 and served as capital of the Federal Republic of Germany from 1973 to 1990. The Unifikation Treaty of 31 August 1990 between the Federal Republic of Germany and the German Democratic Republic declared Berlin to be the capital of the reunified Germany.", "score": 0.8863518, "raw_content": null}, {"url": "https://www.facebook.com/CopernicusEU/posts/-berlin-the-capital-of-germany-is-situated-in-the-countrys-north-east-along-the-/1179062837596026/", "title": "Berlin, the capital of Germany, is situated in the country's north-east ...", "content": "## Copernicus EU's Post ### **Copernicus EU** Berlin, the capital of Germany, is situated in the country's north-east, along the banks of the Spree River. Berlin’s urban environment is interspersed with green spaces, including large parks such as the Tiergarten and forests such as Grunewald, giving it a unique balance between natural and built environments. Berlin is visible in this Copernicus #Sentinel2 image acquired on 1 July 2025. Like Berlin, that's just inner ring Berlin. Als gebürtiger Berliner finde ich das Foto total spannend. Berlin was a village in the 17th C. Berlin ist sooooooooooo groooooooß, es passt noch nicht mal aufs Bildformat. Show us a picture of Gaza from satellite, it must look like Dresden after WWII Everyone Loves Berlin", "score": 0.798077, "raw_content": null}, {"url": "https://www.youtube.com/shorts/U9R_wjxRk0A", "title": "Berlin, the capital of Germany #shorts #shortvideo #berlin ... - YouTube", "content": "What to do in Berlin | Germany | Complete itinerary through the city center. Berlin, the capital of Germany #shorts #shortvideo #berlin", "score": 0.7493996, "raw_content": null}, {"url": "https://www.germany.travel/en/inspiring-germany/berlin.html", "title": "Berlin – the city where anything is possible - Germany Travel", "content": "## **Privacy settings** You can set your consent for each category individually. Further information can be found in the privacy policy. * Nature & Outdoor Activities * Current highlights The sights Berlin has to offer, from the Brandenburg Gate to the Chancellor's Office, bear witness to the history of an entire nation. Germany's capital is home to all the main government buildings, including the historical Reichstag building as the seat of the German parliament. And yet the city somehow remains chilled, with plenty of open spaces where people can go to breathe in some fresh air. ### 16 Highlight natural landscapes ### Old Towns with UNESCO World Heritage status ### Football hotspots: cities with an extra kick", "score": 0.72254705, "raw_content": null}, {"url": "https://www.reddit.com/r/germany/comments/1ipoca1/why_did_berlin_become_the_capital_city_when_the/", "title": "Why did Berlin become the capital city when the two Germanies ...", "content": "Because Berlin has been historically the capital of Germany since 1701 (first Prussia after that German Reich).", "score": 0.7116118, "raw_content": null}], "response_time": 1.14, "request_id": "edd8d4a7-8f70-448d-a59e-d212f5c12897"}
# ================================= Tool Message =================================
# Name: web_search
#
# {"query": "What is the capital of Germany?", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.bmi.bund.de/EN/topics/constitution/state-symbols/capital/capital-city-artikel.html", "title": "Our Capital City - BMI", "content": "Berlin is not only the capital of the Federal Republic of Germany; it is also the seat of Germany’s federal parliament and government. Since 1 September 2006, Berlin’s role as capital of Germany has been enshrined in the Basic Law. Article 22 (1) (1) provides that “Berlin is the capital of the Federal Republic of Germany.” By then, Berlin had witnessed an eventful history. Frankfurt am Main served as seat of the German Confederation from 1815 to 1866; Bonn was the provisional seat of the Federal Government from 1949 to 1973 and served as capital of the Federal Republic of Germany from 1973 to 1990. The Unifikation Treaty of 31 August 1990 between the Federal Republic of Germany and the German Democratic Republic declared Berlin to be the capital of the reunified Germany.", "score": 0.8863518, "raw_content": null}, {"url": "https://www.facebook.com/CopernicusEU/posts/-berlin-the-capital-of-germany-is-situated-in-the-countrys-north-east-along-the-/1179062837596026/", "title": "Berlin, the capital of Germany, is situated in the country's north-east ...", "content": "## Copernicus EU's Post ### **Copernicus EU** Berlin, the capital of Germany, is situated in the country's north-east, along the banks of the Spree River. Berlin’s urban environment is interspersed with green spaces, including large parks such as the Tiergarten and forests such as Grunewald, giving it a unique balance between natural and built environments. Berlin is visible in this Copernicus #Sentinel2 image acquired on 1 July 2025. Like Berlin, that's just inner ring Berlin. Als gebürtiger Berliner finde ich das Foto total spannend. Berlin was a village in the 17th C. Berlin ist sooooooooooo groooooooß, es passt noch nicht mal aufs Bildformat. Show us a picture of Gaza from satellite, it must look like Dresden after WWII Everyone Loves Berlin", "score": 0.798077, "raw_content": null}, {"url": "https://www.youtube.com/shorts/U9R_wjxRk0A", "title": "Berlin, the capital of Germany #shorts #shortvideo #berlin ... - YouTube", "content": "What to do in Berlin | Germany | Complete itinerary through the city center. Berlin, the capital of Germany #shorts #shortvideo #berlin", "score": 0.7493996, "raw_content": null}, {"url": "https://www.germany.travel/en/inspiring-germany/berlin.html", "title": "Berlin – the city where anything is possible - Germany Travel", "content": "## **Privacy settings** You can set your consent for each category individually. Further information can be found in the privacy policy. * Nature & Outdoor Activities * Current highlights The sights Berlin has to offer, from the Brandenburg Gate to the Chancellor's Office, bear witness to the history of an entire nation. Germany's capital is home to all the main government buildings, including the historical Reichstag building as the seat of the German parliament. And yet the city somehow remains chilled, with plenty of open spaces where people can go to breathe in some fresh air. ### 16 Highlight natural landscapes ### Old Towns with UNESCO World Heritage status ### Football hotspots: cities with an extra kick", "score": 0.72254705, "raw_content": null}, {"url": "https://www.reddit.com/r/germany/comments/1ipoca1/why_did_berlin_become_the_capital_city_when_the/", "title": "Why did Berlin become the capital city when the two Germanies ...", "content": "Because Berlin has been historically the capital of Germany since 1701 (first Prussia after that German Reich).", "score": 0.7116118, "raw_content": null}], "response_time": 1.14, "request_id": "edd8d4a7-8f70-448d-a59e-d212f5c12897"}
# ================================== Ai Message ==================================
#
# The capital of Germany is Berlin. It serves as the seat of the federal parliament and government, and its status as the capital has been enshrined in the Basic Law since 2006. Berlin has a rich history and has been the capital since 1701, originally for Prussia and later for the German Reich.
